# %% [markdown]
# Ref principal: https://github.com/eduonix/nlptextclassification/blob/master/NLP%20for%20Text%20Classification%20(Jupyter%20Notebook).ipynb

# %% [markdown]
# ### Imports

# %%
import re
import nltk
#import ftfy 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Carregar dataset

# %%
df = pd.read_excel('datasets/Chamados.xlsx')
df.head()
# Out:
#   Classificação                           Assunto  \
# 0     Inc - Con         PROBLEMA DE CONECTIVIDADE
# 1     Inc - Con                   PC SEM INTERNET
# 2     Inc - Con                   PC SEM INTERNET
# 3     Inc - Con  COMPUTADOR SEM ACESSO A INTERNET
# 4     Inc - Con       COMPUTADOR NÃO ESTÁ LOGANDO
#
#                                            Descricao
# 0                          PROBLEMA DE CONECTIVIDADE
# 1  raquel do bag de dr renato informou que está c...
# 2  vanessa , gab dr carlos barros informou proble...
# 3  Usuário informa que o computador está sem aces...
# 4                       COMPUTADOR NÃO ESTÁ LOGANDO.

# %% [markdown]
# ### Análise inicial

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3195 entries, 0 to 3194
# Data columns (total 3 columns):
# Classificação    2788 non-null object
# Assunto          3195 non-null object
# Descricao        3195 non-null object
# dtypes: object(3)
# memory usage: 75.0+ KB

# %% [markdown]
# - Criando um dataset com os valores nulos da coluna "Classificação"

# %%
df[df['Classificação'].isnull()].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 407 entries, 2788 to 3194
# Data columns (total 3 columns):
# Classificação    0 non-null object
# Assunto          407 non-null object
# Descricao        407 non-null object
# dtypes: object(3)
# memory usage: 12.7+ KB

# %%
df[df['Classificação'].isnull()].to_excel('datasets/Chamados_Não_Classificados.xlsx', index=False)

# %% [markdown]
# - Removendo linhas com a coluna classificação nula

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2788 entries, 0 to 2787
# Data columns (total 3 columns):
# Classificação    2788 non-null object
# Assunto          2788 non-null object
# Descricao        2788 non-null object
# dtypes: object(3)
# memory usage: 87.1+ KB

# %% [markdown]
# ### Verificando a distribuição de classes

# %%
df['Classificação'].value_counts()
# Out:
# Req - Equ    1194
# Req - Sis     962
# Inc - Sis     284
# Inc - Equ     170
# Outros         71
# Inc - Con      55
# Req - Con      52
# Name: Classificação, dtype: int64

# %% [markdown]
# - Deixando as classes de forma binária, apenas Equipamento e Sistema

# %%
df = df[(df['Classificação'] != 'Outros') & (df['Classificação'] != 'Inc - Con') & (df['Classificação'] != 'Req - Con')]
display(df.info())
df['Classificação'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2610 entries, 55 to 2787
# Data columns (total 3 columns):
# Classificação    2610 non-null object
# Assunto          2610 non-null object
# Descricao        2610 non-null object
# dtypes: object(3)
# memory usage: 81.6+ KB
# None
# Req - Equ    1194
# Req - Sis     962
# Inc - Sis     284
# Inc - Equ     170
# Name: Classificação, dtype: int64

# %%
df['Classificação'] = df['Classificação'].apply(lambda c: 'Equipamento' if 'Equ' in c else 'Sistema')
display(df.info())
df['Classificação'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2610 entries, 55 to 2787
# Data columns (total 3 columns):
# Classificação    2610 non-null object
# Assunto          2610 non-null object
# Descricao        2610 non-null object
# dtypes: object(3)
# memory usage: 81.6+ KB
# None
# Equipamento    1364
# Sistema        1246
# Name: Classificação, dtype: int64

# %% [markdown]
# ### Transformando os dados

# %%
le = LabelEncoder()
df['Classificação'] = le.fit_transform(df['Classificação'])
df['Classificação'].value_counts()
# Out:
# 0    1364
# 1    1246
# Name: Classificação, dtype: int64

# %% [markdown]
# 0 para equipamento e 1 para sistema
#
# ### Usando Regex para remoção de caracteres especiais

# %%
# tags html
df['Descricao Atualizada'] = df['Descricao'].str.replace(r'<[^>]*>', '') #<[^>]*> <.*?>
# email 
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'^.+@[^\.].*\.[a-z]{2,}$',
                                 'email')
# URLs 
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$',
                                  'link')
# cifrões de dinheiro 
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'£|\$', 'cifrao') 
# número telefone
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$',
                                  'telefone') 
# números em geral
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'\d+(\.\d+)?', 'numero')
# pontuação
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'[^\w\d\s]', ' ')

df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'[º]', '')
# dois espaços ou mais
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'\s+', ' ')

df['Descricao Atualizada'] = df['Descricao Atualizada'].str.replace(r'^\s+|\s+?$', ' ')
# minusculo
df['Descricao Atualizada'] = df['Descricao Atualizada'].str.lower()
df['Descricao Atualizada']
# Out:
# 55      coloquei para imprimir frente e verso querendo...
# 56             usuário informa que o computador não liga
# 57      usuária entrou em contato alegando que a impre...
# 58      usuário informa que o excel não está funcionando
# 59      usuário entrou em contato alegando que o compu...
#                               ...
# 2783    aprovação de solicitação de funcionalidades có...
# 2784    aprovação de solicitação de funcionalidades có...
# 2785    aprovação de solicitação de funcionalidades có...
# 2786    venho através deste solicitar a publicação sis...
# 2787    cadastramento de diário oficial tce data publi...
# Name: Descricao Atualizada, Length: 2610, dtype: object

# %%
# COMPARAR COM O ORIGINAL
df['Descricao Atualizada'].to_csv('teste.csv')
# Out:
# C:\Users\gfeli\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# - Convertendo caracteres para UTF-8

# %%
df['Descricao Atualizada'] = df['Descricao Atualizada'].apply(lambda d: d.decode(encoding='UTF-8'))
df['Descricao Atualizada']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-c0706eee4a70> in <module>
# ----> 1 df['Descricao Atualizada'] = df['Descricao Atualizada'].apply(lambda d: d.decode(encoding='UTF-8'))
#       2 df['Descricao Atualizada']
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    4040             else:
#    4041                 values = self.astype(object).values
# -> 4042                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4043
#    4044         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-62-c0706eee4a70> in <lambda>(d)
# ----> 1 df['Descricao Atualizada'] = df['Descricao Atualizada'].apply(lambda d: d.decode(encoding='UTF-8'))
#       2 df['Descricao Atualizada']
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
import ftfy 

descricoes = [ftfy.fix_text(descricao) for descricao in processed.values]

descricoes
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c9f688f05331> in <module>()
# ----> 1 import ftfy
#       2
#       3 descricoes = [ftfy.fix_text(descricao) for descricao in processed.values]
#       4
#       5 descricoes
#
# ModuleNotFoundError: No module named 'ftfy'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# - Remover StopWords

# %%
nltk.download('stopwords')

pt_stopwords = set(nltk.corpus.stopwords.words("portuguese"))

df['Descricao Atualizada'] = df['Descricao Atualizada'].apply(lambda d: ' '.join(term for term in d.split() if term not in pt_stopwords))

df['Descricao Atualizada']
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\gfeli\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 55      coloquei imprimir frente verso querendo econom...
# 56                        usuário informa computador liga
# 57      usuária entrou contato alegando impressora loc...
# 58                      usuário informa excel funcionando
# 59      usuário entrou contato alegando computador lig...
#                               ...
# 2783    aprovação solicitação funcionalidades código n...
# 2784    aprovação solicitação funcionalidades código n...
# 2785    aprovação solicitação funcionalidades código n...
# 2786    venho através deste solicitar publicação siste...
# 2787    cadastramento diário oficial tce data publicaç...
# Name: Descricao Atualizada, Length: 2610, dtype: object

# %% [markdown]
# - Stemming

# %%
nltk.download('rslp')

stemmer = nltk.stem.RSLPStemmer()

df['Descricao Atualizada'] = df['Descricao Atualizada'].apply(lambda x: ' '.join(stemmer.stem(term) for term in x.split()))

df['Descricao Atualizada']
# Out:
# [nltk_data] Downloading package rslp to
# [nltk_data]     C:\Users\gfeli\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping stemmers\rslp.zip.
# 55      coloq imprim frent vers quer econom papel agor...
# 56                                  usu inform comput lig
# 57      usuár entr contat aleg impres local recepç dam...
# 58                               usu inform excel funcion
# 59      usu entr contat aleg comput lig entretant brea...
#                               ...
# 2783    aprov solicit funcional códig numer nom mirn a...
# 2784    aprov solicit funcional códig numer nom henriq...
# 2785    aprov solicit funcional códig numer nom joã ed...
# 2786    venh através dest solic public sistem etc api ...
# 2787    cadastr diári ofic tce dat public numer numer ...
# Name: Descricao Atualizada, Length: 2610, dtype: object

# %% [markdown]
# # PAREI AQUI

# %% [markdown]
# ### Obter características

# %%
from nltk.tokenize import word_tokenize
nltk.download('punkt')

all_words = []

for message in processed:
    words = word_tokenize(message)
    for w in words:
        all_words.append(w)
        
all_words = nltk.FreqDist(all_words)

print('Total de palavras: {}'.format(len(all_words)))
print('Mais comuns: {}'.format(all_words.most_common(5)))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Total de palavras: 3671
# Mais comuns: [('numer', 1237), ('solicit', 685), ('process', 653), ('configur', 448), ('inform', 422)]

# %%
#numero de features
word_features = list(all_words.keys())[:1500]

# %%
def find_features(message):
    words = word_tokenize(message)
    features = {}
    for word in word_features:
        features[word] = (word in words)

    return features

# %%
features = find_features(processed[0])
for key, value in features.items():
    if value == True:
        print(key)
# Out:
# problem
# conect

# %%
chamados = list(zip(processed, encoded_classes))

seed = 1
np.random.seed = seed
np.random.shuffle(chamados)

featuresets = [(find_features(text), label) for (text, label) in chamados]

# %%
featuresets[0]
# Out:
# ({'problem': False,
#   'conect': False,
#   'raquel': False,
#   'bag': False,
#   'dr': False,
#   'renat': False,
#   'inform': True,
#   'dificuldad': False,
#   'escut': False,
#   'radi': False,
#   'plenari': False,
#   'gost': False,
#   'sab': False,
#   'q': False,
#   'faz': False,
#   'usuár': False,
#   'are': False,
#   'restrit': False,
#   'pass': False,
#   'instabil': False,
#   'vaness': False,
#   'gab': False,
#   'carl': False,
#   'barr': False,
#   'acess': False,
#   'internet': False,
#   'serviç': False,
#   'restaur': False,
#   'necess': False,
#   'fech': False,
#   'abr': False,
#   'naveg': False,
#   'sistem': False,
#   'retorn': False,
#   'norm': False,
#   'usu': False,
#   'comput': False,
#   'log': False,
#   'resolv': False,
#   'red': False,
#   'bom': False,
#   'dia': False,
#   'consegu': False,
#   'sit': False,
#   'tce': False,
#   'rn': False,
#   'conseg': False,
#   'wif': False,
#   'solicit': False,
#   'apoi': False,
#   'verific': True,
#   'bloquei': False,
#   'email': False,
#   'malici': False,
#   'cheg': False,
#   'caix': False,
#   'postal': False,
#   'instituc': False,
#   'dest': False,
#   'tribun': False,
#   'estaçã': False,
#   'pc': False,
#   'aleg': False,
#   'maquin': False,
#   'est': False,
#   'conex': False,
#   'cab': False,
#   'notebook': False,
#   'coloq': False,
#   'imprim': False,
#   'frent': False,
#   'vers': False,
#   'quer': False,
#   'econom': False,
#   'papel': False,
#   'agor': False,
#   'alerd': False,
#   'pisc': False,
#   'lig': False,
#   'entr': False,
#   'contat': False,
#   'impres': False,
#   'local': False,
#   'recepç': False,
#   'dam': False,
#   'document': False,
#   'excel': False,
#   'funcion': False,
#   'entretant': False,
#   'nobreak': False,
#   'mous': False,
#   'apen': False,
#   'apresent': False,
#   'luz': False,
#   'vermelh': False,
#   'encontr': False,
#   'queim': False,
#   'font': False,
#   'refer': False,
#   'cpu': False,
#   'serv': False,
#   'nº': False,
#   'numer': False,
#   'marc': False,
#   'posi': False,
#   'form': False,
#   'substitu': False,
#   'urg': False,
#   'trat': False,
#   'assess': False,
#   'gabinet': False,
#   'qu': False,
#   'aparec': True,
#   'avis': False,
#   'logon': False,
#   'dispon': False,
#   'inesperad': False,
#   'tel': False,
#   'deslig': False,
#   'etiquet': False,
#   'consig': False,
#   'liber': False,
#   'impress': False,
#   'restaurat': False,
#   'nã': False,
#   'dap': False,
#   'adm': False,
#   'moni': False,
#   'ger': False,
#   'imag': False,
#   'mens': False,
#   'err': False,
#   'tent': False,
#   'ergon': False,
#   'consult': False,
#   'págin': True,
#   'carreg': False,
#   'atol': False,
#   'sigef': False,
#   'looping': False,
#   'infinit': False,
#   'ob': False,
#   'segund': False,
#   'cham': False,
#   'msm': False,
#   'sent': False,
#   'bip': False,
#   'inicial': False,
#   'apropriad': False,
#   'memor': False,
#   'tonn': False,
#   'operac': False,
#   'necessit': False,
#   'instal': False,
#   'softw': False,
#   'certific': False,
#   'digit': False,
#   'trav': False,
#   'pra': True,
#   'assin': False,
#   'pje': False,
#   'tjrn': False,
#   'troc': False,
#   'tecl': False,
#   'respond': False,
#   'salv': False,
#   'process': True,
#   'visit': False,
#   'técn': False,
#   'inic': False,
#   'catrac': False,
#   'cart': False,
#   'pres': False,
#   'impossibilit': False,
#   'saíd': False,
#   'demal': False,
#   'pux': False,
#   'folh': False,
#   'barulh': False,
#   'estranh': False,
#   'presenç': False,
#   'apag': False,
#   'fatur': False,
#   'word': False,
#   'up': False,
#   'numerov': False,
#   'one': False,
#   'tomb': False,
#   'ns': False,
#   'link': False,
#   'const': False,
#   'planilh': False,
#   'eletrôn': False,
#   'memór': False,
#   'ram': False,
#   'random': False,
#   'acces': False,
#   'memory': False,
#   'aleatóri': False,
#   'chei': False,
#   'us': False,
#   'nenhum': False,
#   'aplic': False,
#   'hp': False,
#   'sal': False,
#   'trein': False,
#   'cadastr': False,
#   'ocorrenc': False,
#   'hardw': False,
#   'equip': False,
#   'reinicializ': False,
#   'após': False,
#   'algum': False,
#   'temp': False,
#   'funcionamentoproblem': False,
#   'detect': False,
#   'adob': False,
#   'venh': False,
#   'ocorr': False,
#   'legistcerngovbr': False,
#   'remet': False,
#   'past': False,
#   'envi': True,
#   'endereç': False,
#   'conform': True,
#   'print': False,
#   'abaix': False,
#   'tod': False,
#   'ícon': False,
#   'áre': False,
#   'trabalh': False,
#   'branc': False,
#   'pen': False,
#   'driv': False,
#   'boa': False,
#   'tard': False,
#   'exist': False,
#   'laserjet': False,
#   'enxergál': False,
#   'ser': False,
#   'basic': False,
#   'soment': False,
#   'máquin': False,
#   'ond': False,
#   'via': False,
#   'usb': False,
#   'receb': False,
#   'offlin': False,
#   'inser': False,
#   'despachoinform': False,
#   'contabil': False,
#   'hor': False,
#   'exced': False,
#   'pont': False,
#   'numeronumeronumer': False,
#   'doc': False,
#   'googl': False,
#   'earth': False,
#   'iaramedeirostc': False,
#   'ach': False,
#   'senh': False,
#   'ingl': False,
#   'uma': False,
#   'outr': False,
#   'cor': False,
#   'ros': False,
#   'reinici': False,
#   'mut': False,
#   'token': False,
#   'bloque': False,
#   'forç': False,
#   'bib': False,
#   'lenov': False,
#   'mod': False,
#   'descans': False,
#   'tr': False,
#   'func': False,
#   'bot': False,
#   'ligardeslig': False,
#   'volt': False,
#   'dag': False,
#   'pend': False,
#   'set': False,
#   'iri': False,
#   'mand': False,
#   'calcul': False,
#   'banc': False,
#   'trimestr': False,
#   'corret': False,
#   'bizag': False,
#   'tv': False,
#   'scann': False,
#   'realoc': False,
#   'dev': False,
#   'alag': False,
#   'estabiliz': False,
#   'apc': False,
#   'sol': False,
#   'gnumer': False,
#   'lev': False,
#   'agu': False,
#   'adicion': False,
#   'nh': False,
#   'dá': False,
#   'reconhec': False,
#   'equipamentosproblem': False,
#   'águ': False,
#   'ligaproblem': False,
#   'emit': False,
#   'barulhoproblem': False,
#   'corrig': False,
#   'fot': False,
#   'exib': False,
#   'numeronumer': True,
#   'medi': False,
#   'uso': False,
#   'mal': False,
#   'diret': False,
#   'seguint': False,
#   'microsoft': False,
#   'ole': False,
#   'db': False,
#   'provid': False,
#   'sql': False,
#   'numeroenumer': False,
#   'im': False,
#   'ert': False,
#   'column': False,
#   'nam': False,
#   'or': False,
#   'numb': False,
#   'of': False,
#   'supplied': False,
#   'valu': False,
#   'doe': False,
#   'not': False,
#   'match': False,
#   'tabl': False,
#   'definition': False,
#   'sistemasinformacoesmovdigitarinformacaopinasp': False,
#   'lin': False,
#   'vou': False,
#   'opç': False,
#   'window': False,
#   'ddp': False,
#   'encerr': False,
#   'súbit': False,
#   'falh': False,
#   'autentic': False,
#   'lent': False,
#   'ver': False,
#   'edit': False,
#   'precis': False,
#   'transmit': False,
#   'arqu': False,
#   'celul': False,
#   'import': False,
#   'conclu': False,
#   'utiliz': False,
#   'io': False,
#   'pesso': False,
#   'geral': False,
#   'físic': False,
#   'assinat': False,
#   'send': False,
#   'divers': False,
#   'negativ': False,
#   'mesm': False,
#   'adentr': False,
#   'acontec': False,
#   'leit': False,
#   'diári': False,
#   'possi': False,
#   'poi': False,
#   'pdf': False,
#   'observ': False,
#   'tal': False,
#   'situ': False,
#   'um': False,
#   'i': False,
#   'phon': False,
#   'baix': False,
#   'carát': False,
#   'sele': False,
#   'clic': False,
#   'diálog': False,
#   'adodbparamet': False,
#   'numeroanumeroccnumer': False,
#   'it': False,
#   'pod': False,
#   'coleç': False,
#   'correspond': False,
#   'nom': False,
#   'ord': False,
#   'sistemasprocessoseletivoconprocessoprioritarioasp': False,
#   'diverg': False,
#   'órg': False,
#   'prefeit': False,
#   'joã': False,
#   'relatóri': False,
#   'siop': False,
#   'qual': False,
#   'realiz': False,
#   'test': False,
#   'linh': False,
#   'códig': False,
#   'difer': False,
#   'distribu': False,
#   'dire': False,
#   'despach': False,
#   'sair': False,
#   'minut': False,
#   'public': False,
#   'tend': False,
#   'nov': False,
#   'sucess': False,
#   'automatic': False,
#   'model': False,
#   'configur': False,
#   'moment': False,
#   'exempl': False,
#   'mutirãoda': False,
#   'registr': False,
#   'descrit': False,
#   'anex': True,
#   'si': False,
#   'dp': False,
#   'através': False,
#   'result': False,
#   'suport': False,
#   'din': False,
#   'tráfeg': False,
#   'acim': False,
#   'esper': False,
#   'correç': False,
#   'dív': False,
#   'processoscitaçõescomarc': False,
#   'cit': False,
#   'cuj': False,
#   'municípi': False,
#   'tabel': False,
#   'comarc': False,
#   'homolog': False,
#   'protest': True,
#   'idº': False,
#   'residenc': False,
#   'digitaliz': False,
#   'numero_numer': False,
#   'pens': False,
#   'cri': False,
#   'loten': False,
#   'identific': False,
#   'al': False,
#   'ter': False,
#   'tramit': False,
#   'dap_adm': False,
#   'mot': False,
#   'lot': False,
#   'aind': False,
#   'exclu': False,
#   'produz': False,
#   'san': False,
#   'agradeç': False,
#   'desd': False,
#   'gentil': False,
#   'sempr': False,
#   'demand': False,
#   'att': False,
#   'sheyl': False,
#   'yusk': False,
#   'pagin': False,
#   'pendenc': False,
#   'gest': False,
#   'fundiár': False,
#   'govern': False,
#   'surg': False,
#   'visual': False,
#   'caminh': False,
#   'cont': True,
#   'extern': False,
#   'anális': False,
#   'com': False,
#   'dad': False,
#   'colet': False,
#   'vincul': False,
#   'tip': False,
#   'caron': False,
#   'administr': False,
#   'cronológ': False,
#   'pag': False,
#   'gerenci': False,
#   'fiscal': False,
#   'efetu': False,
#   'acus': False,
#   'vot': False,
#   'feit': False,
#   'vist': False,
#   'concord': False,
#   'rela': False,
#   'retir': False,
#   'arp': False,
#   'contrat': False,
#   'control': False,
#   'admit': False,
#   'númer': False,
#   'fracion': False,
#   'vírgul': False,
#   'entant': False,
#   'engenh': False,
#   'fazs': False,
#   'necessár': False,
#   'man': False,
#   'ra': False,
#   'natur': False,
#   'objet': False,
#   'di': False,
#   'expost': False,
#   'possibil': False,
#   'adequ': False,
#   'modific': False,
#   'aceit': False,
#   'quantit': False,
#   'aba': False,
#   'imped': False,
#   'compos': False,
#   'paut': False,
#   'bas': True,
#   'possu': False,
#   'ativ': False,
#   'cert': False,
#   'relacion': False,
#   'débit': False,
#   'quit': False,
#   'alt': False,
#   'eraç': False,
#   'statu': False,
#   'bol': False,
#   'verifiq': False,
#   'infosseg': False,
#   'talv': False,
#   'letr': False,
#   'vár': False,
#   'mão': False,
#   'especific': False,
#   'decis': False,
#   'monocrá': False,
#   'cryst': False,
#   'report': False,
#   'activex': False,
#   'design': False,
#   'query': False,
#   'engin': False,
#   'hynumeromicrosoftodbc': False,
#   'instruç': False,
#   'associ': False,
#   'prepar': False,
#   'etceportalarearestritasistemasatarelatoriosimprimirrptnovoasp': False,
#   'legil': False,
#   'nao': False,
#   'fat': False,
#   'coneç': False,
#   'fic': False,
#   'inativ': False,
#   'bast': False,
#   'institut': False,
#   'previd': False,
#   'municip': False,
#   'tomé': False,
#   'manoel': False,
#   'francisc': False,
#   'silv': False,
#   'carvalh': False,
#   'cpf': False,
#   'legisl': False,
#   'ata': False,
#   'converting': False,
#   'dat': False,
#   'typ': False,
#   'varch': False,
#   'to': False,
#   'numeric': False,
#   'channel': False,
#   'inclu': False,
#   'entreg': False,
#   'rgf': False,
#   'rre': False,
#   'anual': False,
#   'natal': False,
#   'ano': False,
#   'comprov': False,
#   'caern': False,
#   'bent': False,
#   'trair': False,
#   'failed': False,
#   'open': False,
#   'rowset': False,
#   'detail': False,
#   'numeromicrosoftodbc': False,
#   'driversql': False,
#   'serversubquery': False,
#   'returned': False,
#   'mor': False,
#   'than': False,
#   'thil': False,
#   'is': False,
#   'permitted': False,
#   'when': False,
#   'the': False,
#   'subquery': False,
#   'follow': False,
#   'used': False,
#   'an': False,
#   'expression': False,
#   'etceportalarearestritasistemasrel_orgaosrelatoriosimprimirrptnovoasp': False,
#   'determin': False,
#   'fiz': False,
#   'proced': False,
#   'cerc': False,
#   'nest': False,
#   'seman': False,
#   'seg': False,
#   'permit': False,
#   'limit': False,
#   'env': False,
#   'daquel': False,
#   'selecion': False,
#   'final': False,
#   'julg': False,
#   'remss': True,
#   'inclus': False,
#   'anot': False,
#   'coloc': False,
#   'preench': False,
#   'sistemasprocessoregistraratoasp': False,
#   'ldo': False,
#   'constat': False,
#   'aguard': False,
#   'prossegu': False,
#   'apens': False,
#   'vai': False,
#   'dand': False,
#   'arearestr': False,
#   'favor': False,
#   'reset': False,
#   'pool': False,
#   'ii': False,
#   'execuç': False,
#   'vbscript': False,
#   'numeroanumer': False,
#   'insufici': False,
#   'binary': False,
#   'upload_uploadasp': False,
#   'transpar': False,
#   'jurisdicion': False,
#   'consórci': False,
#   'intermunicip': False,
#   'sane': False,
#   'serr': False,
#   'sant': False,
#   'exercíci': False,
#   'numerobalanç': False,
#   'financ': False,
#   'rebuild': False,
#   'trail': False,
#   'found': False,
#   'orig': False,
#   'messag': False,
#   'startxref': False,
#   'cadinq': False,
#   'respons': False,
#   'prvid': False,
#   'visua': False,
#   'ramal': False,
#   'devolv': False,
#   'irregular': False,
#   'inferi': False,
#   'venc': False,
#   'crít': False,
#   'possibilit': False,
#   'tratas': False,
#   'defês': False,
#   'bat': False,
#   'sob': False,
#   'recuper': False,
#   'usuáriosenh': False,
#   'invál': False,
#   'possível': False,
#   'sext': False,
#   'bimestr': False,
#   'jurdiscion': False,
#   'parcel': False,
#   'mult': False,
#   'port': False,
#   'anumerobafnumer': False,
#   'desp': False,
#   'duplic': False,
#   'informaccedilotilde': False,
#   'terc': False,
#   'camp': False,
#   'grand': False,
#   'grif': False,
#   'amarel': False,
#   'empr': False,
#   'client': False,
#   'pm': False,
#   'carnaub': False,
#   'perceb': False,
#   'divergenc': False,
#   'atual': False,
#   'layout': False,
#   'ped': False,
#   'pessoal': False,
#   'carg': False,
#   'ofic': False,
#   'outubr': False,
#   'novembr': False,
#   'doi': False,
#   'inexist': False,
#   'emb': False,
#   'cumpr': False,
#   'cord': False,
#   'cogeparqu': False,
#   'cogep': False,
#   'arqcogep': False,
#   'destin': False,
#   'intern': False,
#   'ges': False,
#   'usuari': False,
#   'complement': False,
#   'ato': False,
#   'porém': False,
#   'receit': False,
#   'somatóri': False,
#   'anteri': False,
#   'val': False,
#   'backup': False,
#   'extens': False,
#   'usuaacuteri': False,
#   'atraveacut': False,
#   'etc': False,
#   'natilde': False,
#   'ateacut': False,
#   'busc': False,
#   'simpl': False,
#   'localiz': False,
#   'tambeacut': False,
#   'ndeg': False,
#   'companh': False,
#   'serviccedil': False,
#   'urban': False,
#   'tceadmin': False,
#   'deu': False,
#   'full': False,
#   'continu': False,
#   'princip': False,
#   'tcenumer': False,
#   'abl': False,
#   'databas': False,
#   'recepca': False,
#   'und': False,
#   'current': False,
#   'security': False,
#   'context': False,
#   'sistemassiaianaliseconbimestreconsultabimestreasp': False,
#   'supr': False,
#   'fund': False,
#   'gsf': False,
#   'câm': False,
#   'nis': False,
#   'florest': False,
#   'notific': False,
#   'numeronumerotc': False,
#   'diz': False,
#   'deix': False,
#   'percent': False,
#   'zer': False,
#   'époc': False,
#   'disponibil': False,
#   'real': False,
#   'devid': False,
#   'respec': False,
#   'lug': False,
#   'compreend': False,
#   'emiss': False,
#   'analis': False,
#   'corp': False,
#   'segu': False,
#   'portalegr': False,
#   'acar': False,
#   'descr': False,
#   'colun': False,
#   'formul': False,
#   'saúd': False,
#   'mostr': False,
#   'constituc': False,
#   'exe_debit': False,
#   'idinformaca': False,
#   'futur': False,
#   'idcomposicaopautanumer': False,
#   'falt': False,
#   'nome': False,
#   'ocup': False,
#   'independ': False,
#   'nad': False,
#   'jucurutu': False,
#   'recib': False,
#   'defini': False,
#   'xml': False,
#   'assim': False,
#   'provisóri': False,
#   'sofc': False,
#   'mar': False,
#   'conce': False,
#   'oliv': False,
#   'sispatr': False,
#   'modul': False,
#   'funcional': False,
#   'cartóri': False,
#   'motiv': False,
#   'sac': False,
#   'inconsist': False,
#   'exerciacuteci': False,
#   'balanccedil': False,
#   'orcamentari': False,
#   'inclusatilde': False,
#   'vind': False,
#   'importaccedilatilde': False,
#   'siaidp': False,
#   'cacircm': False,
#   'fern': False,
#   'pedroz': False,
#   'mecirc': False,
#   'agost': False,
#   'abert': False,
#   'sid': False,
#   'julh': False,
#   'mencion': False,
#   'agrav': False,
#   'desej': False,
#   'situaccedilatilde': False,
#   'porqu': False,
#   'opccedilatilde': False,
#   'exclusatilde': False,
#   'part': False,
#   'operaccedilatilde': False,
#   'joatilde': False,
#   'venacircnci': False,
#   'sequ': False,
#   'autor': False,
#   'exclus': False,
#   'módul': False,
#   'conssiaiddpanaliserela': False,
#   'açã': False,
#   'shár': False,
#   'so': False,
#   'jewur': False,
#   'dai': False,
#   'ont': False,
#   'exlcu': False,
#   'antig': False,
#   'ieg': False,
#   'tcern': False,
#   'figur': False,
#   'valid': False,
#   'proc': False,
#   'quesistemasprotestoextrajudicialenvioderemessaasp': False,
#   'superi': False,
#   'bolet': False,
#   'aprov': False,
#   'recorr': False,
#   'verd': False,
#   'list': False,
#   'sensibil': False,
#   'indic': False,
#   'prédi': False,
#   'apoacut': False,
#   'bann': False,
#   'curs': False,
#   'samu': False,
#   'disponiacute': False,
#   'aacutere': False,
#   'exp': False,
#   'ip': False,
#   'versotilde': False,
#   'framework': False,
#   'localizaccedilatilde': False,
#   'fs': False,
#   'eacut': False,
#   'notaacute': False,
#   'seguranccedil': False,
#   'relat': False,
#   'poli': False,
#   'seguranç': False,
#   'cort': False,
#   'permiss': False,
#   'açõ': False,
#   'especif': False,
#   'compet': False,
#   'cas': False,
#   'fácil': False,
#   'emoj': False,
#   'chrom': False,
#   'afim': False,
#   'soluc': False,
#   'mant': False,
#   'sigil': False,
#   'prescrev': False,
#   'vári': False,
#   'reenvi': False,
#   'azul': False,
#   'mim': False,
#   'div': False,
#   'posteri': False,
#   'desist': False,
#   'rua': False,
#   'prez': False,
#   'particip': False,
#   'saind': False,
#   'text': False,
#   'pud': False,
#   'semin': False,
#   'sobr': False,
#   'compr': False,
#   'públic': False,
#   'pequen': False,
#   'negóci': False,
#   'foment': False,
#   'desenvolv': False,
#   'inov': False,
#   'ediç': False,
#   'tem': False,
#   'mei': False,
#   'tern': False,
#   'soluç': False,
#   'conflit': False,
#   'âmbit': False,
#   'capacit': False,
#   'avali': False,
#   'dispos': False,
#   'qualqu': False,
#   'esclarec': False,
#   'atencios': False,
#   'sistemasprotestoextrajudicialenvioderemessaasp': False,
#   'implement': False,
#   'guilherm': False,
#   'admiss': False,
#   'numeroº': False,
#   'and': False,
#   'extra': False,
#   'princípi': False,
#   'chamas': False,
#   'expedi': False,
#   'estagi': False,
#   'resoluç': False,
#   'gptc': False,
#   'bols': False,
#   'subsídi': False,
#   'elabor': False,
#   'precípu': False,
#   'celer': False,
#   'evit': False,
#   'manipul': False,
#   'dadosintervenç': False,
#   'human': False,
#   'facil': False,
#   'ambos': False,
#   'cóp': False,
#   'amostr': False,
#   'verificaçãoadn': False,
#   'yar': False,
#   'dant': False,
#   'alin': False,
#   'cristin': False,
#   'post': False,
#   'mai': False,
#   'brev': False,
#   'republic': False,
#   'dúv': False,
#   'relaccedilatilde': False,
#   'municiacutepi': False,
#   'deduccedilatilde': False,
#   'formaccedilatilde': False,
#   'fundeb': False,
#   'fpm': False,
#   'icm': False,
#   'ipv': False,
#   'estatilde': False,
#   'orccedilamentaacuteri': False,
#   'confer': False,
#   'poreacut': False,
#   'relatoacuteri': False,
#   'mav': False,
#   'empenh': False,
#   'liquid': False,
#   'bem': False,
#   'men': False,
#   'estaacut': False,
#   'numerodeg': False,
#   'diferenccedil': False,
#   'er': False,
#   ...},
#  2)

# %%
from sklearn import model_selection

training, testing = model_selection.train_test_split(featuresets, test_size = 0.25, random_state=seed)

print("Treino:", len(training))
print("Teste:", len(testing))
# Out:
# Treino: 2091
# Teste: 697
